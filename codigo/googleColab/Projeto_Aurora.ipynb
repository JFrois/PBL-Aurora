# %% [markdown]
# 👥 Equipe (1CCOA-2026)
#
#  Juan de Lucas Frois       | RM563260\
#  Flavia Roberta Pennachin   | RM561860\
#  Pedro Valente Toledo      | RM570394\
#  Bruno Antonio Santos Silva | RM573180\
#  Renan Mano Otero          | RM573615

# %% [markdown]
# 1) INICIALIZAÇÃO DO AMBIENTE E CONFIGURAÇÃO DO SISTEMA

# %%
import random
import time
import os
from dotenv import load_dotenv

# 1. Carrega as variáveis do arquivo .env para o ambiente
load_dotenv()

# Função para imprimir o quadro
def imprimir_quadro(titulo, linhas):
    largura = 85
    print("-" * largura)
    print(f"| {titulo.center(largura - 4)} |")
    print("|" + " " * (largura - 2) + "|")
    for linha in linhas:
        print(f"| {linha.ljust(largura - 4)} |")
    print("|" + " " * (largura - 2) + "|")
    print("-" * largura)

quantidade_testes = 0
testes_sucessos = 0
testes_falhas = 0
todos_erros = [] # Guarda os erros para a IA analisar depois

print("\n" + "="*85)
print("Sejam bem-vindos ao sistema de telemetria da MISSÃO AURORA".center(85))
print("Iniciando sequência de 3 testes obrigatórios...".center(85))
print("="*85 + "\n")
# Out:
# =====================================================================================
#               Sejam bem-vindos ao sistema de telemetria da MISSÃO AURORA
#                    Iniciando sequência de 3 testes obrigatórios...
# =====================================================================================

# %% [markdown]
# 2) EXECUÇÃO DA ANÁLISE ENERGÉTICA, VERIFICAÇÕES DE SEGURANÇA E RESULTADOS

# %%
while quantidade_testes < 3:
    erros = []
    quantidade_testes += 1

    # --- Simulação de telemetria ---
    temp_interna = random.uniform(10, 35)
    temp_externa = random.uniform(-50, 50)
    integridade_estrutural = random.choice([0, 1])
    capacidade_energia_kwh = random.uniform(1000, 5000)
    carga_energia_pct = random.uniform(0, 100)
    consumo_energia_est = random.uniform(200, 500)
    perdas_energia = random.uniform(10, 50)
    pressao = random.uniform(250, 550)
    modulos_criticos = random.choice(["OK", "FALHA"])



    # --- Processamento da Análise Energética ---
    #Energia disponível antes da decolagem
    energia_bruta_kwh = capacidade_energia_kwh * (carga_energia_pct / 100)

    #Energia restante após decolagem (considerando perdas)
    energia_restante_kwh = energia_bruta_kwh - perdas_energia - consumo_energia_est

    #Autonomia residual em %
    saldo_pos_decolagem_pct = max(0, (energia_restante_kwh / capacidade_energia_kwh) * 100)



    # --- Verificações de segurança ---
    if integridade_estrutural == 0:
        erros.append("FALHA NA INTEGRIDADE ESTRUTURAL")
    if pressao < 300 or pressao > 450:
        erros.append(f"Pressão fora dos padrões: {pressao:.2f} psi")
    if temp_interna < 18 or temp_interna > 25:
        erros.append(f"Temperatura interna fora do padrão: {temp_interna:.2f} C°")
    if modulos_criticos == "FALHA":
        erros.append("FALHA NOS MÓDULOS CRÍTICOS")
    if saldo_pos_decolagem_pct < 80:
        erros.append(f"RISCO DE BLACKOUT: Saldo de {saldo_pos_decolagem_pct:.2f}% (Min: 80%)")


    # Processamento do teste individual
    conteudo_relatorio = [

        "VERIFICAÇÃO DE SEGURANÇA:",
        f"  > Bateria Útil p/ Sistema: {max(0, energia_restante_kwh):.2f} kWh",
        f"  > Custo de Decolagem.....: {consumo_energia_est:.2f} kWh",
        f"  > Autonomia energética pós decolagem...: {saldo_pos_decolagem_pct:.2f}%",
        f"  > Temp. Interna: {temp_interna:.2f} C°",
        f"  > Integridade: OK",
        f"  > Pressão: {pressao:.2f} psi"
    ]

    if not erros:
        testes_sucessos += 1
        status_individual = "TESTE BEM-SUCEDIDO"
        info = f"Rodada {quantidade_testes}: Parâmetros nominais."
    else:
        testes_falhas += 1
        status_individual = "TESTE FALHOU"
        info = f"Rodada {quantidade_testes}: Anomalias detectadas."
        conteudo_relatorio.append("-" * 65)
        conteudo_relatorio.append("ERROS ENCONTRADOS:")
        for erro in erros:
            conteudo_relatorio.append(f"- {erro}")
            todos_erros.append(erro)

    imprimir_quadro(
        f"RELATÓRIO DE RODADA: {quantidade_testes}/3",
        [status_individual, info, "-" * 61] + conteudo_relatorio
        )

# Decisão Final
print("" + "="*65)
print(f"RELATÓRIO DE RODADA: {testes_sucessos} Sucessos | {testes_falhas} Falhas")

if testes_falhas == 0:
    print("STATUS: AUTORIZADO PARA DECOLAGEM! 🚀")
else:
    print("STATUS: ABORTAR MISSÃO! Verifique os erros acima. 🛑")
# Out:
# -------------------------------------------------------------------------------------
# |                              RELATÓRIO DE RODADA: 1/3                             |
# |                                                                                   |
# | TESTE FALHOU                                                                      |
# | Rodada 1: Anomalias detectadas.                                                   |
# | -------------------------------------------------------------                     |
# | VERIFICAÇÃO DE SEGURANÇA:                                                         |
# |   > Bateria Útil p/ Sistema: 472.07 kWh                                           |
# |   > Custo de Decolagem.....: 386.37 kWh                                           |
# |   > Autonomia energética pós decolagem...: 29.09%                                 |
# |   > Temp. Interna: 31.07 C°                                                       |
# |   > Integridade: OK                                                               |
# |   > Pressão: 521.54 psi                                                           |
# | -----------------------------------------------------------------                 |
# | ERROS ENCONTRADOS:                                                                |
# | - Pressão fora dos padrões: 521.54 psi                                            |
# | - Temperatura interna fora do padrão: 31.07 C°                                    |
# | - FALHA NOS MÓDULOS CRÍTICOS                                                      |
# | - RISCO DE BLACKOUT: Saldo de 29.09% (Min: 80%)                                   |
# |                                                                                   |
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# |                              RELATÓRIO DE RODADA: 2/3                             |
# |                                                                                   |
# | TESTE FALHOU                                                                      |
# | Rodada 2: Anomalias detectadas.                                                   |
# | -------------------------------------------------------------                     |
# | VERIFICAÇÃO DE SEGURANÇA:                                                         |
# |   > Bateria Útil p/ Sistema: 0.00 kWh                                             |
# |   > Custo de Decolagem.....: 227.31 kWh                                           |
# |   > Autonomia energética pós decolagem...: 0.00%                                  |
# |   > Temp. Interna: 23.15 C°                                                       |
# |   > Integridade: OK                                                               |
# |   > Pressão: 410.54 psi                                                           |
# | -----------------------------------------------------------------                 |
# | ERROS ENCONTRADOS:                                                                |
# | - FALHA NA INTEGRIDADE ESTRUTURAL                                                 |
# | - RISCO DE BLACKOUT: Saldo de 0.00% (Min: 80%)                                    |
# |                                                                                   |
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# |                              RELATÓRIO DE RODADA: 3/3                             |
# |                                                                                   |
# | TESTE FALHOU                                                                      |
# | Rodada 3: Anomalias detectadas.                                                   |
# | -------------------------------------------------------------                     |
# | VERIFICAÇÃO DE SEGURANÇA:                                                         |
# |   > Bateria Útil p/ Sistema: 0.00 kWh                                             |
# |   > Custo de Decolagem.....: 433.12 kWh                                           |
# |   > Autonomia energética pós decolagem...: 0.00%                                  |
# |   > Temp. Interna: 12.89 C°                                                       |
# |   > Integridade: OK                                                               |
# |   > Pressão: 331.06 psi                                                           |
# | -----------------------------------------------------------------                 |
# | ERROS ENCONTRADOS:                                                                |
# | - Temperatura interna fora do padrão: 12.89 C°                                    |
# | - FALHA NOS MÓDULOS CRÍTICOS                                                      |
# | - RISCO DE BLACKOUT: Saldo de 0.00% (Min: 80%)                                    |
# |                                                                                   |
# -------------------------------------------------------------------------------------
# =================================================================
# RELATÓRIO DE RODADA: 0 Sucessos | 3 Falhas
# STATUS: ABORTAR MISSÃO! Verifique os erros acima. 🛑

# %% [markdown]
# 3) ANÁLISE ASSISTIDA POR IA:
#
# Classificação dos dados  |   Identificação de possíveis anomalias  |  Sugestões de risco

# %%
from google import genai
from dotenv import load_dotenv


load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")



if not api_key:
    print("Falha: variável GEMINI_API_KEY não encontrada no arquivo .env ou no ambiente.")
else:
    client = genai.Client(api_key=api_key)


# Initialize erros_formatadas to prevent NameError
erros_formatadas = ""

# Montando o prompt dinâmico para a IA baseando-se nos resultados reais
if testes_sucessos == 3:
    print(">>> STATUS FINAL: PRONTO PARA DECOLAR! 🚀")
    print("Todos os testes foram aprovados. Iniciando contagem de ignição...\n")
    prompt_ia = "Aja como um engenheiro de voo sênior. O foguete Aurora passou nos 3 testes de telemetria com 100% de sucesso. Escreva um breve relatório de duas linhas parabenizando a equipe e autorizando o lançamento em português do Brasil."
else:
    print(">>> STATUS FINAL: DECOLAGEM ABORTADA! ❌")
    print(f"A missão requer 3 sucessos consecutivos. Detectamos {testes_falhas} falha(s).")
    print(
            f"{time.localtime().tm_hour:02d}:"
            f"{time.localtime().tm_min:02d}:"
            f"{time.localtime().tm_sec:02d} - "
            "A equipe de engenharia está investigando as falhas.\n"
    )

    # Passa a lista de erros reais para o Gemini explicar
    erros_formatadas = ", ".join(sorted(set(todos_erros)))
    prompt_ia = f"Aja como um engenheiro de voo sênior. O lançamento do foguete Aurora foi abortado pois falhou em {testes_falhas} de 3 testes. As anomalias detectadas foram: {erros_formatadas}. Em português do Brasil, explique de forma técnica e concisa por que essas anomalias impedem o lançamento e o que a equipe deve investigar."

#Chama IA com o contexto correto
print("--- ANÁLISE DO DIRETOR DE VOO (IA) ---")
try:
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt_ia
    )
    print(response.text)
except Exception as e:
    print(f"Falha na comunicação com a IA: {e}")

print("="*65)
# Out:
# >>> STATUS FINAL: DECOLAGEM ABORTADA! ❌
# A missão requer 3 sucessos consecutivos. Detectamos 3 falha(s).
# 16:28:54 - A equipe de engenharia está investigando as falhas.
#
# --- ANÁLISE DO DIRETOR DE VOO (IA) ---
# **Relatório de Aborto de Lançamento – Foguete Aurora**
#
# **Atenção, Equipe.**
#
# Conforme o protocolo, o lançamento do foguete Aurora foi abortado após a falha em 3 de 3 testes pré-voo. As anomalias detectadas são críticas e confirmam que as condições para um lançamento seguro e bem-sucedido não foram atendidas.
#
# ---
#
# **I. Por Que as Anomalias Impedem o Lançamento (Análise de Risco)**
#
# 1.  **FALHA NA INTEGRIDADE ESTRUTURAL:**
#     *   **Impacto:** Este é um impeditivo *absoluto*. Uma falha na integridade estrutural significa que o veículo não possui a resistência necessária para suportar as cargas aerodinâmicas, térmicas e gravitacionais extremas durante a ascensão. O risco é de desintegração catastrófica do foguete, com potencial perda total do veículo e da carga útil, além de representar um grave risco de segurança para o complexo de lançamento e áreas adjacentes.
#
# 2.  **FALHA NOS MÓDULOS CRÍTICOS:**
#     *   **Impacto:** Módulos críticos são componentes vitais para a propulsão, guiamento, controle, navegação ou subsistemas de energia. A falha nesses módulos implica uma perda imediata ou iminente de funcionalidades essenciais. Lançar nessas condições resultaria em perda de controle do veículo, incapacidade de atingir a trajetória ou órbita pretendida, ou falha completa da missão.
#
# 3.  **Pressão fora dos padrões: 521.54 psi:**
#     *   **Impacto:** Sem o contexto do valor nominal e da tolerância, qualquer pressão "fora dos padrões" em um sistema pressurizado (propelente, pneumático, hidráulico) é inaceitável. Se for excessiva, pode levar à ruptura de tanques ou linhas. Se for insuficiente, pode comprometer o fluxo de propelente aos motores (cavitação, redução de empuxo) ou a atuação de sistemas de controle. Ambas as situações podem causar uma falha catastrófica da propulsão ou controle de voo.
#
# 4.  **RISCO DE BLACKOUT: Saldo de 0.00% (Min: 80%) e 29.09% (Min: 80%):**
#     *   **Impacto:** Estas leituras indicam uma falha crítica nos subsistemas de energia elétrica. Um saldo de 0% ou 29.09% contra um mínimo de 80% significa que não há energia suficiente para alimentar os aviônicos, telemetria, sistemas de controle de voo, ignitores de motor, válvulas ou atuadores. O lançamento resultaria em um *blackout* imediato, perda total de comunicação e controle do veículo, levando à falha da missão e à perda do foguete logo após a ignição ou nos primeiros segundos de voo.
#
# 5.  **Temperatura interna fora do padrão: 12.89 C° e 31.07 C°:**
#     *   **Impacto:** Temperaturas internas fora da faixa operacional projetada comprometem a confiabilidade e o desempenho dos sistemas eletrônicos, baterias e sensores. Temperaturas muito baixas (como 12.89 C°, dependendo do sistema) podem causar lentidão ou falha de componentes eletrônicos, reduzir a eficiência das baterias ou alterar as propriedades dos propelentes. Temperaturas elevadas (31.07 C°, também dependendo do limite) podem levar ao superaquecimento de componentes, falha de isolamento ou degradação de desempenho, resultando em comportamento errático ou falha permanente de subsistemas.
#
# ---
#
# **II. O Que a Equipe Deve Investigar (Plano de Ação Imediato)**
#
# A prioridade é a identificação da causa raiz de cada anomalia. Sugiro a seguinte abordagem:
#
# 1.  **FALHA NA INTEGRIDADE ESTRUTURAL:**
#     *   **Investigação:** Iniciar imediatamente uma análise de falha detalhada. Revisar toda a documentação de projeto, fabricação e montagem. Realizar inspeções não destrutivas (NDT) extensivas em toda a estrutura do veículo, com foco em áreas de alta tensão e interfaces. Testar amostras de materiais e verificar a conformidade dos processos de soldagem/união.
#
# 2.  **FALHA NOS MÓDULOS CRÍTICOS:**
#     *   **Investigação:** Isolar os módulos afetados e realizar testes de bancada exaustivos para replicar a falha. Analisar logs de dados dos testes abortados para identificar padrões. Revisar a integração de hardware/software, bem como as interfaces elétricas e de comunicação. Verificar a redundância dos sistemas críticos, se houver.
#
# 3.  **Pressão fora dos padrões: 521.54 psi:**
#     *   **Investigação:** Inspecionar e recalibrar todos os transdutores de pressão e sensores do sistema em questão. Verificar a integridade e funcionamento de válvulas reguladoras, válvulas de alívio e linhas de pressurização quanto a obstruções, vazamentos ou falhas mecânicas. Realizar testes de estanqueidade e de ciclagem.
#
# 4.  **RISCO DE BLACKOUT:**
#     *   **Investigação:** Realizar um diagnóstico completo do subsistema de energia elétrica. Isso inclui verificação da saúde das baterias (capacidade, resistência interna), inspeção dos sistemas de gerenciamento de carga, retificadores, inversores e barramentos de distribuição de energia. Avaliar a lógica de controle de potência e o consumo de corrente dos subsistemas.
#
# 5.  **Temperatura interna fora do padrão:**
#     *   **Investigação:** Verificar a calibração e o posicionamento dos sensores de temperatura internos. Analisar a eficiência do sistema de controle térmico do veículo (isolamento, aquecedores, resfriadores, se aplicável). Comparar as leituras com os modelos térmicos do foguete e identificar possíveis fontes de calor inesperadas ou falhas no isolamento.
#
# ---
#
# A equipe de engenharia deve formar grupos de trabalho focados em cada uma dessas áreas, com relatórios diários de progresso. A segurança da tripulação (se houver) e do patrimônio é primordial. Não haverá novas tentativas de lançamento até que todas as anomalias sejam plenamente compreendidas, corrigidas e verificadas através de um regime de testes rigoroso.
#
# Conto com a expertise e dedicação de todos.
# =================================================================

# %% [markdown]
# ## 4) REFLEXÃO CRÍTICA: MISSÃO AURORA
#
# A exploração espacial é o reflexo dos valores da humanidade. Na **Missão Aurora**, a telemetria não apenas monitora máquinas, mas protege vidas e fundamenta uma presença humana ética e consciente.
#
# ### ⚖️ Ética e Responsabilidade
# A exploração espacial não é uma fuga dos problemas terrestres, mas uma busca por soluções globais. O espaço deve ser um **bem comum**, focado na ciência e na cooperação, evitando a militarização e garantindo que o progresso tecnológico beneficie toda a sociedade, não apenas grupos restritos.
#
# ### 🛰️ Sustentabilidade e Lixo Espacial
# A órbita terrestre é um recurso finito. Para evitar o **Efeito Kessler** (colisões em cadeia), a missão adota protocolos de **Desórbita Programada**: cada componente possui um fim de ciclo planejado, garantindo que a "estrada espacial" permaneça limpa e segura para as futuras gerações.
#
#
# ### 🤝 Impacto Social do Lançamento Tripulado
# Enviar seres humanos ao espaço gera transformações profundas na estrutura social:
#
# * **Inspiração STEM:** O "Efeito Apollo" atrai jovens para carreiras científicas e quebra barreiras sociais através da representatividade.
# * **Diplomacia Global:** A manutenção da vida em órbita exige cooperação internacional, promovendo o diálogo e reforçando a identidade planetária (**Overview Effect**).
# * **Avanços na Medicina:** A telemetria e o suporte à vida impulsionam a telemedicina, cirurgias robóticas e tratamentos de perda óssea/muscular para idosos na Terra.
#
# * **Cultura de Segurança:** Os rigorosos protocolos de falha zero e as tecnologias de reciclagem de recursos (água e ar) são aplicados hoje em indústrias críticas e na gestão de desastres ambientais.
#
# ---
#
# > **Conclusão:** Decolar exige mais que combustível; exige o compromisso de proteger quem parte, quem fica e o ambiente que nos cerca.
