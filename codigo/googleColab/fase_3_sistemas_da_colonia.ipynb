# %% [markdown]
# 👥 Equipe (1CCOA-2026)
#
#  Juan de Lucas Frois       | RM563260\
#  Flavia Roberta Pennachin   | RM561860\
#  Pedro Valente Toledo      | RM570394\
#  Bruno Antonio Santos Silva | RM573180\
#  Renan Mano Otero          | RM573615

# %% [markdown]
# ## 1. Organizando os dados da colônia
#
# Para a etapa de modelagem e estruturação dos dados foi projetada com foco em eficiência, legibilidade e facilidade de acesso. A arquitetura foi implementada na função memoria_colonia_aurora(), utilizando as práticas fundamentais da disciplina de Estruturas de Dados.
#
#
# ### Uso de Dicionários Nativos (Estruturas Chave-Valor)
# Os dicionários permitem o mapeamento direto via chaves textuais (etiquetas). Isso garante uma busca de altíssima performance e torna o código autodocumentado. Qualquer desenvolvedor da equipe consegue entender o que o dado representa.
#
#
# ### Organização Hierárquica e Aninhamento
# Os sistemas da colônia foram divididos em níveis lógicos através de dicionários aninhados, refletindo com precisão a infraestrutura real da base espacial:
#
# $$\text{colonia\_aurora\_dados} \longrightarrow \text{sistema\_energetico} \longrightarrow \text{tipo\_geracao} \longrightarrow \text{solar / eolico}$$
#
# Essa hierarquia facilita a navegação entre os subsistemas. Para os blocos de código subsequentes, o acesso aos dados ocorre de forma intuitiva e limpa, utilizando caminhos estruturados como:
#
# dados["sistema_energetico"]["tipo_geracao"]["solar"]["geracao_atual"]

# %%
# ==================================================
#  --- Estruturação dos Dados da Colônia Aurora --- 
# ==================================================

def memoria_colonia_aurora():       

# Configurando a hierarquia dos dados e os subsistemas da base usando estruturas de chave-valor 
    colonia_aurora_dados = {
        "sistema_energetico": {
            "tipo_geracao": {
                "solar": {
                    "nome": "Painéis Fotovoltaicos",
                    "status": "ativo",
                    "capacidade_max_mw": 120.0,
                    "geracao_atual": 50.0,
                    "consumo_atual": 2.5  
                },
                "eolico": {
                    "nome": "Turbinas Eólicas",
                    "status": "ativo",
                    "capacidade_max_mw": 80.0,
                    "geracao_atual": 30.0,
                    "consumo_atual": 1.5  
                }
            },
            "reserva_baterias": {
                "capacidade_total_mwh": 600.0,
                "nivel_atual_mwh": 150.0,
                "nivel_atual_porcentagem": 25.0,  
                "nivel_critico_porcentagem": 20.0
            }
        },        
        "clima": {
            "temperatura_C": 18.5,
            "vento_km_h": 36.0
        }, 
        
        "sistemas_consumo": {
            # --- SISTEMAS ESSENCIAIS (Suporte à Vida) ---
            "suporte_medico": {
                "nome": "Suporte Médico",
                "consumo_atual_mw": 25.0,
                "essencial": True,
                "status": "ligado",
            },
            "habitacao": {
                "nome": "Habitação",
                "consumo_atual_mw": 30.0,
                "essencial": True,
                "status": "ligado",
            },
            # --- SISTEMAS NÃO ESSENCIAIS (Gerenciáveis em Crise) ---
            "logistica": {
                "nome": "Logística",
                "consumo_atual_mw": 15.0,
                "essencial": False,
                "status": "ligado",
            },
            "laboratorio": {
                "nome": "Laboratório",
                "consumo_atual_mw": 20.0,
                "essencial": False,
                "status": "ligado",
            }
        }
    }
    return colonia_aurora_dados
