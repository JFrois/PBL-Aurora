# %% [markdown]
# 1) Importando os dados do arquivo "dados_telemetria_nave.CSV"

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../dados_telemetria_nave.csv')
df.head()
# Out:
#              timestamp  temp_interna_c  temp_externa_c  \
# 0  2026-03-30T10:00:00           20.86           27.27
# 1  2026-03-30T10:00:01           20.39           14.08
# 2  2026-03-30T10:00:02           20.84           25.87
# 3  2026-03-30T10:00:03           21.56           20.54
# 4  2026-03-30T10:00:04           23.67           18.95
#
#    integridade_estrutural  energia_capacidade_kwh  energia_carga_pct  \
# 0                       1                    5000              99.00
# 1                       1                    5000              98.95
# 2                       1                    5000              98.90
# 3                       1                    5000              98.86
# 4                       1                    5000              98.81
#
#    energia_consumo_decolagem_kwh  energia_perdas_kwh  pressao_tanques_psi  \
# 0                           1200               19.97               435.20
# ...

# %% [markdown]
# 2) Conhecendo os dados do arquivo dados_telemetria_nave.CSV

# %%
df.shape
# Out:
# (500, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   timestamp                      500 non-null    object
#  1   temp_interna_c                 500 non-null    float64
#  2   temp_externa_c                 500 non-null    float64
#  3   integridade_estrutural         500 non-null    int64
#  4   energia_capacidade_kwh         500 non-null    int64
#  5   energia_carga_pct              500 non-null    float64
#  6   energia_consumo_decolagem_kwh  500 non-null    int64
#  7   energia_perdas_kwh             500 non-null    float64
#  8   pressao_tanques_psi            500 non-null    float64
#  9   status_modulos                 500 non-null    object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        temp_interna_c  temp_externa_c  integridade_estrutural  \
# count      500.000000      500.000000              500.000000
# mean        21.546820       19.977300                0.982000
# std          2.310974        5.646076                0.133084
# min         17.510000       10.020000                0.000000
# 25%         19.555000       15.730000                1.000000
# 50%         21.505000       19.705000                1.000000
# 75%         23.455000       24.660000                1.000000
# max         25.480000       29.980000                1.000000
#
#        energia_capacidade_kwh  energia_carga_pct  \
# count                   500.0         500.000000
# mean                   5000.0          87.000000
# std                       0.0           6.949094
# min                    5000.0          75.000000
# 25%                    5000.0          80.997500
# 50%                    5000.0          87.000000
# 75%                    5000.0          93.002500
# ...

# %% [markdown]
# 3.
